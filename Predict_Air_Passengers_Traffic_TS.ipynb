# %% [markdown]
# # Predict the Number of Passengers for air travel in the next month

# %% [markdown]
# ### Load Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from keras.utils import np_utils
# Out:
# Using TensorFlow backend.

# %%
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
# !ls -l 'drive/My Drive/AIML/SequentialModels'
# Out:
# total 659
# -rw------- 1 root root   2182 Apr 12 03:41  airline-passengers.csv
# -rw------- 1 root root 183904 Apr 12 07:48 'google (1).csv'
# -rw------- 1 root root  48240 Apr 12 06:04  Lab0_Word2vec_gensim_movie_data.ipynb
# -rw------- 1 root root 215415 May 31 20:02 'Lab1_TimeSeries - Air Passengers Traffic.ipynb'
# -rw------- 1 root root 186016 Apr 12 03:41  Lab2_stockPriceDirectionPrediction_v2.ipynb
# -rw------- 1 root root   8544 Apr 12 03:41 'LSTM Sentiment Analysis Kaggle.ipynb'
# -rw------- 1 root root  20445 Jun  1 05:07  Predict_Air_Passengers_Traffic_TS.ipynb
# drwx------ 2 root root   4096 Jun  1 03:23  savedModels
# -rw------- 1 root root   1763 Apr 12 07:48  Tractor-Sales.csv
# -rw------- 1 root root    915 Apr 12 07:48  wsbSalesData.csv
# -rw------- 1 root root    151 May 31 19:28  wsbSalesData.gsheet

# %%
df = pd.read_csv('/content/drive/My Drive/AIML/SequentialModels/airline-passengers.csv')
df.sort_index(inplace=True)
df.shape
# Out:
# (144, 2)

# %%
df.head(4)
# Out:
#      Month  Passengers
# 0  1949-01         112
# 1  1949-02         118
# 2  1949-03         132
# 3  1949-04         129

# %%
df.tail(4)
# Out:
#        Month  Passengers
# 140  1960-09         508
# 141  1960-10         461
# 142  1960-11         390
# 143  1960-12         432

# %%
#Plot of complete dataset
ax = df.plot(figsize=(10,5), color ='black')

# %% [markdown]
# #### Observations:
# - We see a nice snake pattern going up
# - There is seasonality in the data.
# - There is an upward trend in the data
# - The seasonality is expanding.Initially the seasonality curve(s-shape in each season) is small, but as we move from left to right, the seasonality is increasing.
# - The variance is increasig as we move from left to right, because the ups and downs are huge in the latter part.

# %% [markdown]
# ### Data Preprocessing

# %%
#Check for null values
df.isnull().sum()
# Out:
# Month         0
# Passengers    0
# dtype: int64

# %%
#Check Data Range
print('Min', np.min(df))
print('Max', np.max(df))
# Out:
# Min Month         1949-01
# Passengers        104
# dtype: object
# Max Month         1960-12
# Passengers        622
# dtype: object

# %%
#Drop Month columns as it is not used for prediction.The time column is only a primary key
df.drop("Month", axis=1, inplace=True)

# %%
#Normalize the data
#Use MinMax Scaler to scale the data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(df)

# %%
#we can get original data from scaled data using inverse_transform
#scaled.inverse_transform(scaler)

# %% [markdown]
# ### Split Data

# %%
#70% examples will used for training (in the begining)
train_size = int(len(scaled) * 0.70)

#30% will be used for Test
#test_size = len(scaled - train_size)
test_size = len(scaled) - train_size

print("Train size and Test size are : ",train_size, test_size, len(scaled))
# Out:
# Train size and Test size are :  100 44 144

# %%
#Split the data
train = scaled[0:train_size, :]
test = scaled[train_size: len(scaled), :]
print('train Size : {}\ntest Size: {}'.format(len(train), len(test)))
print('train Shape : {}\ntest Shape: {}'.format(train.shape, test.shape))
print('\ntrain :\n {}\n\ntest : {}'.format(train[0:2], test[0:2]))
# Out:
# train Size : 100
# test Size: 44
# train Shape : (100, 1)
# test Shape: (44, 1)
#
# train :
#  [[0.01544402]
#  [0.02702703]]
#
# test : [[0.48455598]
#  [0.61389961]]

# %% [markdown]
# ### Build Input and Output data
# for both Training and Test based on the window or past history size

# %%
#window - how long the sequence will be or how many time steps to predict
#function to create X_train, y_train and X_test, y_test
def create_dataset(dataset, window=1):
    
    dataX, dataY = [], []
    
    for i in range(len(dataset)-window):
        #print(i, i+window)

        #X_train
        a = dataset[i:(i+window), 0]

        #y_train
        b = dataset[i+window, 0]

        #print(a, b)
        dataX.append(a)
        dataY.append(b)
    
    return np.array(dataX), np.array(dataY)

# %%
#Create Input and Output
window_size =1
X_train, y_train = create_dataset(train, window_size)
X_test, y_test = create_dataset(test, window_size)

# %%
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (99, 1) (99,)
# (43, 1) (43,)

# %%
X_train[0:5]
# Out:
# array([[0.01544402],
#        [0.02702703],
#        [0.05405405],
#        [0.04826255],
#        [0.03281853]])

# %%
#The second datapoint of X_train, will be first datapoint of y_train
y_train[0:5]
# Out:
# array([0.02702703, 0.05405405, 0.04826255, 0.03281853, 0.05984556])

# %% [markdown]
# ###Compare multiple classical regression
# #####Classical machine learning Algorithms : LR, KNN, SVR, DT (CART), RF
# - Linear regression
# - K-nearest neighbors regression
# - Support vector machines regression
# - Decision trees regression
# - Random Forest regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
models = []
models.append(('LR', LinearRegression()))
models.append(('KNN', KNeighborsRegressor()))
models.append(('SVM', SVR()))
models.append(('CART1', DecisionTreeRegressor(max_depth=10)))
models.append(('CART2', DecisionTreeRegressor(max_depth=4)))
models.append(('RF', RandomForestRegressor()))

# %%
# Model Performance of each model
# evaluate each model in turn
results = []
names = []
for name, model in models:
    model = model.fit(X_train, y_train)
    msg = "%s: %f (%f) " % (name, model.score(X_train, y_train), model.score(X_test, y_test))
    print("Model name: Train-score(Test-score)")
    print(msg)
# Out:
# Model name: Train-score(Test-score)
# LR: 0.900005 (0.580570)
# Model name: Train-score(Test-score)
# KNN: 0.903753 (-0.421975)
# Model name: Train-score(Test-score)
# SVM: 0.846570 (-2.303297)
# Model name: Train-score(Test-score)
# CART1: 0.982429 (-0.066860)
# Model name: Train-score(Test-score)
# CART2: 0.929672 (-0.338667)
# Model name: Train-score(Test-score)
# RF: 0.964812 (-0.166352)

# %% [markdown]
# #### Observations:
# - In this case LR model is an overfit model, with 90% Train R2 and 58%
# - All the remaining models are performing very poorly with a negative Test R2, and can be discarded

# %%
## Let us consider Linear regression
#model = LinearRegression()
#model.fit(X_train, y_train)

# %%
## Let us consider DecisionTree regression
model = DecisionTreeRegressor()
model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')

# %%
#Predit values on X_train and X_test
trainPredict = model.predict(X_train)
testPredict = model.predict(X_test)

#Reshape  trainPredict
trainPredict = trainPredict.reshape(-1,1)

#Un-normalize the predited data in trainPredict
trainPredict = scaler.inverse_transform(trainPredict)

#Reshape  testPredict
testPredict = testPredict.reshape(-1,1)

#Un-normalize the predited data in testPredict
testPredict = scaler.inverse_transform(testPredict)

# %%
trainPredict.shape
# Out:
# (99, 1)

# %%
testPredict.shape
# Out:
# (43, 1)

# %%
#shift train predictions for plotting
trainPredictPlot = np.empty_like(scaled)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[window_size:len(trainPredict)+window_size, :] = trainPredict

#shift test predictions for plotting
testPredictPlot = np.empty_like(scaled)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(window_size*2):len(scaled), :] = testPredict

print(trainPredictPlot.shape, testPredictPlot.shape)
print(trainPredictPlot[0:3], trainPredictPlot[98:101])
print(testPredictPlot[100:103], testPredictPlot[141:])
# Out:
# (144, 1) (144, 1)
# [[  nan]
#  [118. ]
#  [123.5]] [[356.]
#  [348.]
#  [ nan]]
# [[ nan]
#  [306.]
#  [405.]] [[405.]
#  [405.]
#  [355.]]

# %%
# plot baseline, trainPredict and testPredict
plt.figure(figsize=(10,5))
labels = ['baseline', 'trainPredict', 'testPredict']

#baseline plot
plt.plot(scaler.inverse_transform(scaled), color='black')

#Train Predicted Plot
plt.plot(trainPredictPlot, color='orange')

#Test Predicted Plot
plt.plot(testPredictPlot, color='red')

plt.legend(labels)
plt.show()

# %% [markdown]
# ### Observations:
# - Black plot is original data, orange is trainpredicted and red is testPredicted
# - red is far away from black plot.There is a deviation of red from black, but orange is closer to black plot in the beginning
# - The trainPredictions are approximately close to baseline predictions, so we can say the model is doing well on train dataset
# - The testPredictions are far away from baseline predictions, so we can say the model is not performing well on test dataset
# - This is the reason Decision tree is performing very badly on the data and it is clear/evident from this plot
# - We can increase this model furthur by using LSTM

# %% [markdown]
# #### The LSTM network expects the input data (X) to be provided with a specific array structure in the form of : [samples, time steps, features]

# %%
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (99, 1) (99,)
# (43, 1) (43,)

# %%
print(X_train.shape[0], X_train.shape[1], 1)
print(X_test.shape[0], X_test.shape[1], 1)
# Out:
# 99 1 1
# 43 1 1

# %%
#Make it 3 Dimensional Data - needed for LSTM
#dim1: No of rows
#dim2: No of months into the past which we use to predict the present(past history)
#dim3: No of features
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
print(X_train.shape)
print(X_test.shape)
# Out:
# (99, 1, 1)
# (43, 1, 1)

# %% [markdown]
# ### Build the Model

# %%
#Clear the session before adding a model
tf.keras.backend.clear_session()

#Add a Sequential container
model = tf.keras.Sequential()

#Add the LSTM layer with some Memory Units.
#No of Memory Units=32 indicates, the number of floating values in Long Term Memory(LTM) as well as Short Term Memory(STM)
#In current Keras implementation, the number of floating values in LTM = number of floating values in STM
model.add(tf.keras.layers.LSTM(32, input_shape=(window_size, 1)))

#For all Regression and LSTM problems, the final layer is always a dense layer with one output
model.add(tf.keras.layers.Dense(1))

#For compiing the model, use adam as the optimizer and since it is a regression problem, we use mse as the loss function
model.compile(optimizer='adam', loss='mse')

# %%
#Add model checkpoint to save the best model weights.The best model is one with least validation loss
LSTMcheckpoint_path = "/content/drive/My Drive/AIML/SequentialModels/savedModels/lstm.ckpt"
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=LSTMcheckpoint_path,
                                                 save_weights_only=True,
                                                 monitor='val_loss',
                                                 mode = 'min',
                                                 save_best_only=True,
                                                 verbose=1)

# %%
#Run the model for 1500 epochs , with batch size of 32, save weights of best model using callbacks
model.fit(X_train, y_train, epochs=1500, validation_data=(X_test, y_test), batch_size=32, callbacks=[cp_callback])
# Out:
# Streaming output truncated to the last 5000 lines.
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0020
# Epoch 00251: val_loss did not improve from 0.00967
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0021 - val_loss: 0.0099
# Epoch 252/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0024
# Epoch 00252: val_loss did not improve from 0.00967
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0021 - val_loss: 0.0099
# Epoch 253/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0019
# Epoch 00253: val_loss did not improve from 0.00967
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0021 - val_loss: 0.0098
# Epoch 254/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0026
# Epoch 00254: val_loss did not improve from 0.00967
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 0.0098
# Epoch 255/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0020
# Epoch 00255: val_loss did not improve from 0.00967
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 0.0098
# Epoch 256/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0032
# Epoch 00256: val_loss did not improve from 0.00967
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 257/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0016
# Epoch 00257: val_loss did not improve from 0.00967
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 258/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0020
# Epoch 00258: val_loss did not improve from 0.00967
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 259/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0023
# Epoch 00259: val_loss did not improve from 0.00967
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 0.0098
# Epoch 260/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0021
# Epoch 00260: val_loss did not improve from 0.00967
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0022 - val_loss: 0.0099
# Epoch 261/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0022
# Epoch 00261: val_loss did not improve from 0.00967
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0022 - val_loss: 0.0098
# Epoch 262/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0022
# Epoch 00262: val_loss did not improve from 0.00967
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 263/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0021
# Epoch 00263: val_loss did not improve from 0.00967
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 264/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0022
# Epoch 00264: val_loss did not improve from 0.00967
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0021 - val_loss: 0.0098
# Epoch 265/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0019
# Epoch 00265: val_loss did not improve from 0.00967
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0021 - val_loss: 0.0098
# Epoch 266/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0017
# Epoch 00266: val_loss did not improve from 0.00967
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 0.0098
# Epoch 267/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0022
# Epoch 00267: val_loss did not improve from 0.00967
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 0.0098
# Epoch 268/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0019
# Epoch 00268: val_loss did not improve from 0.00967
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0021 - val_loss: 0.0098
# Epoch 269/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0024
# Epoch 00269: val_loss did not improve from 0.00967
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 270/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0021
# Epoch 00270: val_loss did not improve from 0.00967
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 271/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0028
# Epoch 00271: val_loss improved from 0.00967 to 0.00967, saving model to /content/drive/My Drive/AIML/SequentialModels/savedModels/lstm.ckpt
# 4/4 [==============================] - 0s 92ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 272/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0017
# Epoch 00272: val_loss improved from 0.00967 to 0.00966, saving model to /content/drive/My Drive/AIML/SequentialModels/savedModels/lstm.ckpt
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 273/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0027
# Epoch 00273: val_loss did not improve from 0.00966
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0021 - val_loss: 0.0098
# Epoch 274/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0019
# Epoch 00274: val_loss did not improve from 0.00966
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 0.0099
# Epoch 275/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0024
# Epoch 00275: val_loss did not improve from 0.00966
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 0.0102
# Epoch 276/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0011
# Epoch 00276: val_loss did not improve from 0.00966
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0023 - val_loss: 0.0105
# Epoch 277/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0022
# Epoch 00277: val_loss did not improve from 0.00966
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0024 - val_loss: 0.0104
# Epoch 278/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0022
# Epoch 00278: val_loss did not improve from 0.00966
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0023 - val_loss: 0.0100
# Epoch 279/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0031
# Epoch 00279: val_loss did not improve from 0.00966
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 280/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0020
# Epoch 00280: val_loss improved from 0.00966 to 0.00962, saving model to /content/drive/My Drive/AIML/SequentialModels/savedModels/lstm.ckpt
# 4/4 [==============================] - 0s 98ms/step - loss: 0.0021 - val_loss: 0.0096
# Epoch 281/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0023
# Epoch 00281: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 282/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0018
# Epoch 00282: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 283/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0024
# Epoch 00283: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 284/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0016
# Epoch 00284: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 285/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0012
# Epoch 00285: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 286/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0016
# Epoch 00286: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 287/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0019
# Epoch 00287: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 0.0098
# Epoch 288/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0021
# Epoch 00288: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 0.0099
# Epoch 289/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0024
# Epoch 00289: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0021 - val_loss: 0.0099
# Epoch 290/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0028
# Epoch 00290: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0021 - val_loss: 0.0098
# Epoch 291/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0026
# Epoch 00291: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0020 - val_loss: 0.0098
# Epoch 292/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0014
# Epoch 00292: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 0.0099
# Epoch 293/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0017
# Epoch 00293: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0021 - val_loss: 0.0099
# Epoch 294/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0020
# Epoch 00294: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0021 - val_loss: 0.0099
# Epoch 295/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0022
# Epoch 00295: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0021 - val_loss: 0.0099
# Epoch 296/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0022
# Epoch 00296: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0021 - val_loss: 0.0099
# Epoch 297/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0019
# Epoch 00297: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 0.0099
# Epoch 298/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0024
# Epoch 00298: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0021 - val_loss: 0.0099
# Epoch 299/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0018
# Epoch 00299: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0021 - val_loss: 0.0098
# Epoch 300/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0026
# Epoch 00300: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0021 - val_loss: 0.0098
# Epoch 301/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0022
# Epoch 00301: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0020 - val_loss: 0.0098
# Epoch 302/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0026
# Epoch 00302: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 0.0099
# Epoch 303/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0025
# Epoch 00303: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0021 - val_loss: 0.0099
# Epoch 304/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0018
# Epoch 00304: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0021 - val_loss: 0.0099
# Epoch 305/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0021
# Epoch 00305: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 306/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0021
# Epoch 00306: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 307/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0017
# Epoch 00307: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 308/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0029
# Epoch 00308: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0020 - val_loss: 0.0097
# Epoch 309/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0025
# Epoch 00309: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0021 - val_loss: 0.0098
# Epoch 310/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0020
# Epoch 00310: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0021 - val_loss: 0.0098
# Epoch 311/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0022
# Epoch 00311: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 312/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0020
# Epoch 00312: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 313/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0016
# Epoch 00313: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 314/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0025
# Epoch 00314: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 315/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0014
# Epoch 00315: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 316/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0018
# Epoch 00316: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 317/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0016
# Epoch 00317: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 318/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0022
# Epoch 00318: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 319/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0021
# Epoch 00319: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 320/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0020
# Epoch 00320: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 321/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0011
# Epoch 00321: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0021 - val_loss: 0.0098
# Epoch 322/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0014
# Epoch 00322: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 323/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0020
# Epoch 00323: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 324/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0019
# Epoch 00324: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 325/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0022
# Epoch 00325: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 326/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0019
# Epoch 00326: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 327/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0022
# Epoch 00327: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 328/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0019
# Epoch 00328: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 329/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0021
# Epoch 00329: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 330/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0020
# Epoch 00330: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 331/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0027
# Epoch 00331: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 332/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0020
# Epoch 00332: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 333/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0024
# Epoch 00333: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 334/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0019
# Epoch 00334: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0021 - val_loss: 0.0098
# Epoch 335/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0022
# Epoch 00335: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0021 - val_loss: 0.0098
# Epoch 336/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0022
# Epoch 00336: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0021 - val_loss: 0.0098
# Epoch 337/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0021
# Epoch 00337: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0021 - val_loss: 0.0098
# Epoch 338/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0023
# Epoch 00338: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 339/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0017
# Epoch 00339: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0020 - val_loss: 0.0097
# Epoch 340/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0017
# Epoch 00340: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 341/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0019
# Epoch 00341: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 342/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0022
# Epoch 00342: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 343/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0028
# Epoch 00343: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 344/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0028
# Epoch 00344: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0020 - val_loss: 0.0097
# Epoch 345/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0016
# Epoch 00345: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0021 - val_loss: 0.0098
# Epoch 346/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0022
# Epoch 00346: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 347/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0019
# Epoch 00347: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 348/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0027
# Epoch 00348: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 349/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0027
# Epoch 00349: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 0.0098
# Epoch 350/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0020
# Epoch 00350: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 0.0098
# Epoch 351/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0021
# Epoch 00351: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0021 - val_loss: 0.0098
# Epoch 352/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0025
# Epoch 00352: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 353/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0023
# Epoch 00353: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0020 - val_loss: 0.0097
# Epoch 354/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0025
# Epoch 00354: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0020 - val_loss: 0.0097
# Epoch 355/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0017
# Epoch 00355: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 356/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0027
# Epoch 00356: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 357/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0023
# Epoch 00357: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 358/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0021
# Epoch 00358: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 359/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0021
# Epoch 00359: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0021 - val_loss: 0.0098
# Epoch 360/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0023
# Epoch 00360: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 0.0098
# Epoch 361/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0019
# Epoch 00361: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 362/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0022
# Epoch 00362: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 363/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0018
# Epoch 00363: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 364/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0019
# Epoch 00364: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 365/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0018
# Epoch 00365: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 366/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0024
# Epoch 00366: val_loss did not improve from 0.00962
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0021 - val_loss: 0.0096
# Epoch 367/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0022
# Epoch 00367: val_loss improved from 0.00962 to 0.00961, saving model to /content/drive/My Drive/AIML/SequentialModels/savedModels/lstm.ckpt
# 4/4 [==============================] - 0s 48ms/step - loss: 0.0021 - val_loss: 0.0096
# Epoch 368/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0020
# Epoch 00368: val_loss improved from 0.00961 to 0.00956, saving model to /content/drive/My Drive/AIML/SequentialModels/savedModels/lstm.ckpt
# 4/4 [==============================] - 0s 80ms/step - loss: 0.0021 - val_loss: 0.0096
# Epoch 369/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0022
# Epoch 00369: val_loss did not improve from 0.00956
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0021 - val_loss: 0.0096
# Epoch 370/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0024
# Epoch 00370: val_loss did not improve from 0.00956
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0021 - val_loss: 0.0096
# Epoch 371/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0020
# Epoch 00371: val_loss did not improve from 0.00956
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 0.0096
# Epoch 372/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0019
# Epoch 00372: val_loss improved from 0.00956 to 0.00955, saving model to /content/drive/My Drive/AIML/SequentialModels/savedModels/lstm.ckpt
# 4/4 [==============================] - 0s 44ms/step - loss: 0.0021 - val_loss: 0.0095
# Epoch 373/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0023
# Epoch 00373: val_loss did not improve from 0.00955
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0021 - val_loss: 0.0095
# Epoch 374/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0018
# Epoch 00374: val_loss did not improve from 0.00955
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0021 - val_loss: 0.0096
# Epoch 375/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0018
# Epoch 00375: val_loss did not improve from 0.00955
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0021 - val_loss: 0.0096
# Epoch 376/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0015
# Epoch 00376: val_loss did not improve from 0.00955
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0021 - val_loss: 0.0096
# Epoch 377/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0018
# Epoch 00377: val_loss did not improve from 0.00955
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0020 - val_loss: 0.0096
# Epoch 378/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0016
# Epoch 00378: val_loss did not improve from 0.00955
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0021 - val_loss: 0.0096
# Epoch 379/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0022
# Epoch 00379: val_loss did not improve from 0.00955
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0021 - val_loss: 0.0096
# Epoch 380/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0017
# Epoch 00380: val_loss did not improve from 0.00955
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0020 - val_loss: 0.0096
# Epoch 381/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0022
# Epoch 00381: val_loss did not improve from 0.00955
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 382/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0024
# Epoch 00382: val_loss did not improve from 0.00955
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0021 - val_loss: 0.0098
# Epoch 383/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0018
# Epoch 00383: val_loss did not improve from 0.00955
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 384/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0014
# Epoch 00384: val_loss did not improve from 0.00955
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 0.0096
# Epoch 385/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0020
# Epoch 00385: val_loss did not improve from 0.00955
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0021 - val_loss: 0.0096
# Epoch 386/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0025
# Epoch 00386: val_loss did not improve from 0.00955
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0021 - val_loss: 0.0096
# Epoch 387/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0018
# Epoch 00387: val_loss did not improve from 0.00955
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 0.0096
# Epoch 388/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0022
# Epoch 00388: val_loss did not improve from 0.00955
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0020 - val_loss: 0.0096
# Epoch 389/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0025
# Epoch 00389: val_loss did not improve from 0.00955
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0021 - val_loss: 0.0096
# Epoch 390/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0019
# Epoch 00390: val_loss did not improve from 0.00955
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 0.0096
# Epoch 391/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0020
# Epoch 00391: val_loss did not improve from 0.00955
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0020 - val_loss: 0.0096
# Epoch 392/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0020
# Epoch 00392: val_loss did not improve from 0.00955
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0021 - val_loss: 0.0096
# Epoch 393/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0029
# Epoch 00393: val_loss did not improve from 0.00955
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0020 - val_loss: 0.0097
# Epoch 394/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0012
# Epoch 00394: val_loss did not improve from 0.00955
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0021 - val_loss: 0.0099
# Epoch 395/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0022
# Epoch 00395: val_loss did not improve from 0.00955
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0021 - val_loss: 0.0098
# Epoch 396/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0014
# Epoch 00396: val_loss did not improve from 0.00955
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0021 - val_loss: 0.0096
# Epoch 397/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0026
# Epoch 00397: val_loss did not improve from 0.00955
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0020 - val_loss: 0.0096
# Epoch 398/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0029
# Epoch 00398: val_loss did not improve from 0.00955
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 399/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0020
# Epoch 00399: val_loss did not improve from 0.00955
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 400/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0024
# Epoch 00400: val_loss did not improve from 0.00955
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 401/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0020
# Epoch 00401: val_loss did not improve from 0.00955
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0021 - val_loss: 0.0096
# Epoch 402/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0017
# Epoch 00402: val_loss did not improve from 0.00955
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 0.0096
# Epoch 403/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0021
# Epoch 00403: val_loss did not improve from 0.00955
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0020 - val_loss: 0.0096
# Epoch 404/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0020
# Epoch 00404: val_loss did not improve from 0.00955
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0021 - val_loss: 0.0096
# Epoch 405/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0018
# Epoch 00405: val_loss did not improve from 0.00955
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0021 - val_loss: 0.0098
# Epoch 406/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0029
# Epoch 00406: val_loss did not improve from 0.00955
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0022 - val_loss: 0.0099
# Epoch 407/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0028
# Epoch 00407: val_loss did not improve from 0.00955
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0022 - val_loss: 0.0098
# Epoch 408/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0020
# Epoch 00408: val_loss did not improve from 0.00955
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 409/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0026
# Epoch 00409: val_loss did not improve from 0.00955
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0021 - val_loss: 0.0096
# Epoch 410/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0017
# Epoch 00410: val_loss did not improve from 0.00955
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 0.0098
# Epoch 411/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0022
# Epoch 00411: val_loss did not improve from 0.00955
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 412/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0018
# Epoch 00412: val_loss did not improve from 0.00955
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 413/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0020
# Epoch 00413: val_loss did not improve from 0.00955
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0021 - val_loss: 0.0096
# Epoch 414/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0021
# Epoch 00414: val_loss did not improve from 0.00955
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0020 - val_loss: 0.0096
# Epoch 415/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0023
# Epoch 00415: val_loss did not improve from 0.00955
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0020 - val_loss: 0.0096
# Epoch 416/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0017
# Epoch 00416: val_loss did not improve from 0.00955
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 0.0096
# Epoch 417/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0017
# Epoch 00417: val_loss did not improve from 0.00955
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 418/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0015
# Epoch 00418: val_loss did not improve from 0.00955
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0021 - val_loss: 0.0098
# Epoch 419/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0017
# Epoch 00419: val_loss did not improve from 0.00955
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 0.0098
# Epoch 420/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0023
# Epoch 00420: val_loss did not improve from 0.00955
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0021 - val_loss: 0.0098
# Epoch 421/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0023
# Epoch 00421: val_loss did not improve from 0.00955
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 422/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0021
# Epoch 00422: val_loss did not improve from 0.00955
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0021 - val_loss: 0.0096
# Epoch 423/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0018
# Epoch 00423: val_loss did not improve from 0.00955
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0020 - val_loss: 0.0096
# Epoch 424/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0022
# Epoch 00424: val_loss did not improve from 0.00955
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 0.0096
# Epoch 425/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0019
# Epoch 00425: val_loss did not improve from 0.00955
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 0.0096
# Epoch 426/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0024
# Epoch 00426: val_loss did not improve from 0.00955
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0021 - val_loss: 0.0096
# Epoch 427/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0020
# Epoch 00427: val_loss did not improve from 0.00955
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0021 - val_loss: 0.0096
# Epoch 428/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0021
# Epoch 00428: val_loss did not improve from 0.00955
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0020 - val_loss: 0.0096
# Epoch 429/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0019
# Epoch 00429: val_loss did not improve from 0.00955
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 0.0096
# Epoch 430/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0028
# Epoch 00430: val_loss improved from 0.00955 to 0.00953, saving model to /content/drive/My Drive/AIML/SequentialModels/savedModels/lstm.ckpt
# 4/4 [==============================] - 0s 52ms/step - loss: 0.0021 - val_loss: 0.0095
# Epoch 431/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0021
# Epoch 00431: val_loss improved from 0.00953 to 0.00953, saving model to /content/drive/My Drive/AIML/SequentialModels/savedModels/lstm.ckpt
# 4/4 [==============================] - 0s 79ms/step - loss: 0.0021 - val_loss: 0.0095
# Epoch 432/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0020
# Epoch 00432: val_loss did not improve from 0.00953
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0020 - val_loss: 0.0096
# Epoch 433/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0020
# Epoch 00433: val_loss did not improve from 0.00953
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 0.0096
# Epoch 434/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0014
# Epoch 00434: val_loss improved from 0.00953 to 0.00953, saving model to /content/drive/My Drive/AIML/SequentialModels/savedModels/lstm.ckpt
# 4/4 [==============================] - 0s 85ms/step - loss: 0.0021 - val_loss: 0.0095
# Epoch 435/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0022
# Epoch 00435: val_loss improved from 0.00953 to 0.00950, saving model to /content/drive/My Drive/AIML/SequentialModels/savedModels/lstm.ckpt
# 4/4 [==============================] - 0s 42ms/step - loss: 0.0020 - val_loss: 0.0095
# Epoch 436/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0021
# Epoch 00436: val_loss did not improve from 0.00950
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0020 - val_loss: 0.0095
# Epoch 437/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0026
# Epoch 00437: val_loss did not improve from 0.00950
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0020 - val_loss: 0.0095
# Epoch 438/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0025
# Epoch 00438: val_loss did not improve from 0.00950
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0020 - val_loss: 0.0096
# Epoch 439/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0019
# Epoch 00439: val_loss did not improve from 0.00950
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0021 - val_loss: 0.0096
# Epoch 440/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0014
# Epoch 00440: val_loss did not improve from 0.00950
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0020 - val_loss: 0.0096
# Epoch 441/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0021
# Epoch 00441: val_loss did not improve from 0.00950
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0020 - val_loss: 0.0096
# Epoch 442/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0024
# Epoch 00442: val_loss did not improve from 0.00950
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0021 - val_loss: 0.0096
# Epoch 443/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0018
# Epoch 00443: val_loss did not improve from 0.00950
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0020 - val_loss: 0.0096
# Epoch 444/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0014
# Epoch 00444: val_loss did not improve from 0.00950
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0021 - val_loss: 0.0096
# Epoch 445/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0024
# Epoch 00445: val_loss did not improve from 0.00950
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0021 - val_loss: 0.0096
# Epoch 446/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0022
# Epoch 00446: val_loss did not improve from 0.00950
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0021 - val_loss: 0.0096
# Epoch 447/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0028
# Epoch 00447: val_loss did not improve from 0.00950
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0021 - val_loss: 0.0096
# Epoch 448/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0019
# Epoch 00448: val_loss did not improve from 0.00950
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0021 - val_loss: 0.0096
# Epoch 449/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0018
# Epoch 00449: val_loss did not improve from 0.00950
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 450/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0023
# Epoch 00450: val_loss did not improve from 0.00950
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 451/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0018
# Epoch 00451: val_loss did not improve from 0.00950
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 452/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0019
# Epoch 00452: val_loss did not improve from 0.00950
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 0.0096
# Epoch 453/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0028
# Epoch 00453: val_loss did not improve from 0.00950
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0021 - val_loss: 0.0099
# Epoch 454/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0018
# Epoch 00454: val_loss did not improve from 0.00950
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0022 - val_loss: 0.0101
# Epoch 455/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0025
# Epoch 00455: val_loss did not improve from 0.00950
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0023 - val_loss: 0.0100
# Epoch 456/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0025
# Epoch 00456: val_loss did not improve from 0.00950
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0022 - val_loss: 0.0097
# Epoch 457/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0022
# Epoch 00457: val_loss did not improve from 0.00950
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0021 - val_loss: 0.0096
# Epoch 458/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0018
# Epoch 00458: val_loss did not improve from 0.00950
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0021 - val_loss: 0.0096
# Epoch 459/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0016
# Epoch 00459: val_loss did not improve from 0.00950
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0021 - val_loss: 0.0096
# Epoch 460/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0013
# Epoch 00460: val_loss did not improve from 0.00950
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 0.0095
# Epoch 461/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0023
# Epoch 00461: val_loss did not improve from 0.00950
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0020 - val_loss: 0.0096
# Epoch 462/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0021
# Epoch 00462: val_loss did not improve from 0.00950
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 0.0096
# Epoch 463/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0019
# Epoch 00463: val_loss did not improve from 0.00950
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0021 - val_loss: 0.0096
# Epoch 464/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0021
# Epoch 00464: val_loss did not improve from 0.00950
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0020 - val_loss: 0.0096
# Epoch 465/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0019
# Epoch 00465: val_loss did not improve from 0.00950
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 466/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0024
# Epoch 00466: val_loss did not improve from 0.00950
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 467/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0028
# Epoch 00467: val_loss did not improve from 0.00950
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0021 - val_loss: 0.0096
# Epoch 468/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0027
# Epoch 00468: val_loss did not improve from 0.00950
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0021 - val_loss: 0.0095
# Epoch 469/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0022
# Epoch 00469: val_loss did not improve from 0.00950
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0020 - val_loss: 0.0095
# Epoch 470/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0016
# Epoch 00470: val_loss did not improve from 0.00950
# ...
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0020 - val_loss: 0.0100
# Epoch 1427/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0017
# Epoch 01427: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0020 - val_loss: 0.0099
# Epoch 1428/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0018
# Epoch 01428: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0020 - val_loss: 0.0097
# Epoch 1429/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0018
# Epoch 01429: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0020 - val_loss: 0.0093
# Epoch 1430/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0018
# Epoch 01430: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0020 - val_loss: 0.0093
# Epoch 1431/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0022
# Epoch 01431: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0020 - val_loss: 0.0092
# Epoch 1432/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0020
# Epoch 01432: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0020 - val_loss: 0.0095
# Epoch 1433/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0018
# Epoch 01433: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0020 - val_loss: 0.0095
# Epoch 1434/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0016
# Epoch 01434: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0020 - val_loss: 0.0094
# Epoch 1435/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0025
# Epoch 01435: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0020 - val_loss: 0.0095
# Epoch 1436/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0020
# Epoch 01436: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0020 - val_loss: 0.0097
# Epoch 1437/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0020
# Epoch 01437: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0020 - val_loss: 0.0098
# Epoch 1438/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0022
# Epoch 01438: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0020 - val_loss: 0.0093
# Epoch 1439/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0015
# Epoch 01439: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0020 - val_loss: 0.0092
# Epoch 1440/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0022
# Epoch 01440: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0020 - val_loss: 0.0094
# Epoch 1441/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0020
# Epoch 01441: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0020 - val_loss: 0.0094
# Epoch 1442/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0019
# Epoch 01442: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0020 - val_loss: 0.0092
# Epoch 1443/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0031
# Epoch 01443: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0020 - val_loss: 0.0089
# Epoch 1444/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0022
# Epoch 01444: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0020 - val_loss: 0.0088
# Epoch 1445/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0021
# Epoch 01445: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0020 - val_loss: 0.0089
# Epoch 1446/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0019
# Epoch 01446: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0020 - val_loss: 0.0090
# Epoch 1447/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0022
# Epoch 01447: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0020 - val_loss: 0.0090
# Epoch 1448/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0017
# Epoch 01448: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0020 - val_loss: 0.0089
# Epoch 1449/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0021
# Epoch 01449: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0020 - val_loss: 0.0089
# Epoch 1450/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0018
# Epoch 01450: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0020 - val_loss: 0.0089
# Epoch 1451/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0017
# Epoch 01451: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0020 - val_loss: 0.0091
# Epoch 1452/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0026
# Epoch 01452: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0020 - val_loss: 0.0094
# Epoch 1453/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0019
# Epoch 01453: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0020 - val_loss: 0.0099
# Epoch 1454/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0013
# Epoch 01454: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0020 - val_loss: 0.0096
# Epoch 1455/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0019
# Epoch 01455: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0020 - val_loss: 0.0088
# Epoch 1456/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0015
# Epoch 01456: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0021 - val_loss: 0.0086
# Epoch 1457/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0025
# Epoch 01457: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0021 - val_loss: 0.0085
# Epoch 1458/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0026
# Epoch 01458: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0022 - val_loss: 0.0086
# Epoch 1459/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0025
# Epoch 01459: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0021 - val_loss: 0.0090
# Epoch 1460/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0018
# Epoch 01460: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0020 - val_loss: 0.0091
# Epoch 1461/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0023
# Epoch 01461: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0020 - val_loss: 0.0092
# Epoch 1462/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0022
# Epoch 01462: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0020 - val_loss: 0.0093
# Epoch 1463/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0017
# Epoch 01463: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0020 - val_loss: 0.0091
# Epoch 1464/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0017
# Epoch 01464: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0020 - val_loss: 0.0088
# Epoch 1465/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0019
# Epoch 01465: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0020 - val_loss: 0.0089
# Epoch 1466/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0018
# Epoch 01466: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0020 - val_loss: 0.0093
# Epoch 1467/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0021
# Epoch 01467: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0020 - val_loss: 0.0093
# Epoch 1468/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0022
# Epoch 01468: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0020 - val_loss: 0.0094
# Epoch 1469/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0014
# Epoch 01469: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0020 - val_loss: 0.0095
# Epoch 1470/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0015
# Epoch 01470: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0020 - val_loss: 0.0095
# Epoch 1471/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0019
# Epoch 01471: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0020 - val_loss: 0.0096
# Epoch 1472/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0024
# Epoch 01472: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0020 - val_loss: 0.0095
# Epoch 1473/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0022
# Epoch 01473: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0020 - val_loss: 0.0093
# Epoch 1474/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0011
# Epoch 01474: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0020 - val_loss: 0.0092
# Epoch 1475/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0020
# Epoch 01475: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0020 - val_loss: 0.0093
# Epoch 1476/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0020
# Epoch 01476: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0020 - val_loss: 0.0093
# Epoch 1477/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0016
# Epoch 01477: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0020 - val_loss: 0.0091
# Epoch 1478/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0020
# Epoch 01478: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0020 - val_loss: 0.0090
# Epoch 1479/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0017
# Epoch 01479: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0020 - val_loss: 0.0088
# Epoch 1480/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0014
# Epoch 01480: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0020 - val_loss: 0.0088
# Epoch 1481/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0016
# Epoch 01481: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0020 - val_loss: 0.0091
# Epoch 1482/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0021
# Epoch 01482: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0020 - val_loss: 0.0093
# Epoch 1483/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0020
# Epoch 01483: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0020 - val_loss: 0.0092
# Epoch 1484/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0018
# Epoch 01484: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0020 - val_loss: 0.0088
# Epoch 1485/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0024
# Epoch 01485: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0020 - val_loss: 0.0087
# Epoch 1486/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0015
# Epoch 01486: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0020 - val_loss: 0.0087
# Epoch 1487/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0021
# Epoch 01487: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0020 - val_loss: 0.0088
# Epoch 1488/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0018
# Epoch 01488: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0020 - val_loss: 0.0089
# Epoch 1489/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0021
# Epoch 01489: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0020 - val_loss: 0.0089
# Epoch 1490/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0026
# Epoch 01490: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0020 - val_loss: 0.0088
# Epoch 1491/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0021
# Epoch 01491: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0020 - val_loss: 0.0088
# Epoch 1492/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0028
# Epoch 01492: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0020 - val_loss: 0.0089
# Epoch 1493/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0025
# Epoch 01493: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0020 - val_loss: 0.0090
# Epoch 1494/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0015
# Epoch 01494: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0020 - val_loss: 0.0091
# Epoch 1495/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0020
# Epoch 01495: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0020 - val_loss: 0.0093
# Epoch 1496/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0016
# Epoch 01496: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0020 - val_loss: 0.0094
# Epoch 1497/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0015
# Epoch 01497: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0020 - val_loss: 0.0094
# Epoch 1498/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0017
# Epoch 01498: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0020 - val_loss: 0.0093
# Epoch 1499/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0025
# Epoch 01499: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0020 - val_loss: 0.0091
# Epoch 1500/1500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0017
# Epoch 01500: val_loss did not improve from 0.00849
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0020 - val_loss: 0.0090

# %% [markdown]
# ### Load saved weights

# %%
# Loads the weights
model.load_weights(LSTMcheckpoint_path)

# %% [markdown]
# ### Model evaluation

# %%
#Train loss (trainMSE)
train_loss_and_metrics = model.evaluate(X_train, y_train)
print(train_loss_and_metrics)

#Test loss (testMSE)
test_loss_and_metrics = model.evaluate(X_test, y_test)
print(test_loss_and_metrics)
# Out:
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0023
# 0.0022998563945293427
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0085
# 0.008491056971251965

# %% [markdown]
# ### Model Prediction
# ### Get Predictions for both Training and Test Data

# %%
#Get prediction for both Training and Test Data
trainPredict = model.predict(X_train)
testPredict = model.predict(X_test)

# %%
print(X_train.shape, y_train.shape, trainPredict.shape)
# Out:
# (99, 1, 1) (99,) (99, 1)

# %%
print(X_test.shape, y_test.shape, testPredict.shape)
# Out:
# (43, 1, 1) (43,) (43, 1)

# %%
print(X_train[0],y_train[0], trainPredict[0])
print(X_test[0],y_test[0], testPredict[0])
# Out:
# [[0.01544402]] 0.02702702702702703 [0.04332863]
# [[0.48455598]] 0.6138996138996139 [0.49350747]

# %% [markdown]
# ### Model Performance
# ### Train and Test  R2 and RMSE

# %%
from sklearn.metrics import r2_score, mean_squared_error

# %%
#Train R2 and Test R2
print("Train R2 (Accuracy) is ",r2_score(y_train, trainPredict))
print("Test R2 (Accuracy) is ",r2_score(y_test, testPredict))
# Out:
# Train R2 (Accuracy) is  0.8855780848562604
# Test R2 (Accuracy) is  0.612267564315315

# %%
#Train MSE and Test MSE
print("Train mse (loss) is ",mean_squared_error(y_train, trainPredict))
print("Test mse (loss) is ",mean_squared_error(y_test, testPredict))
# Out:
# Train mse (loss) is  0.002299856354175037
# Test mse (loss) is  0.00849105699303145

# %%
#Train RMSE and Test RMSE
print("Train rmse (loss) is ",np.sqrt(mean_squared_error(y_train, trainPredict)))
print("Test rmse (loss) is ",np.sqrt(mean_squared_error(y_test, testPredict)))
# Out:
# Train rmse (loss) is  0.04795681759849205
# Test rmse (loss) is  0.09214693154430836

# %% [markdown]
# ## Prediction for a new input value

# %%
myInput = np.reshape(scaler.transform(pd.DataFrame({"Passengers":[700]})),(1,1,1))
int(scaler.inverse_transform(model.predict(myInput)))
# Out:
# 646

# %% [markdown]
# - If the number of passengers in current month is 700, then no of passengers in the next month would be 646

# %%
myInput = np.reshape(scaler.transform(pd.DataFrame({"Passengers":[730]})),(1,1,1))
int(scaler.inverse_transform(model.predict(myInput)))
# Out:
# 668

# %% [markdown]
# - If the number of passengers in current month is 730, then no of passengers in the next month would be 668

# %%
myInput = np.reshape(scaler.transform(pd.DataFrame({"Passengers":[390, 432]})), (2,1,1))
print(scaler.inverse_transform(model.predict(np.reshape(myInput, (2, 1, 1)))))
np.int32(scaler.inverse_transform(model.predict(np.reshape(myInput, (2, 1, 1)))))
# Out:
# [[391.55423]
#  [429.11807]]
# array([[391],
#        [429]], dtype=int32)

# %% [markdown]
# - If the number of passengers in current month is 390, then no of passengers in the next month would be 391 and if number of passengers in current month is 432, then no of passengers in the next month would be 429

# %%
#Un-normalize the predited data
trainPredict = model.predict(X_train)
testPredict = model.predict(X_test)

trainPredict = scaler.inverse_transform(trainPredict)
testPredict = scaler.inverse_transform(testPredict)

# %% [markdown]
# ### Plot to visualize Baseline, Train Predictions and Test Predictions

# %%
# shift train predictions for plotting
trainPredictPlot = np.empty_like(scaled)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[window_size:len(trainPredict)+window_size, :] = trainPredict

# shift test predictions for plotting
testPredictPlot = np.empty_like(scaled)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(window_size*2):len(scaled), :] = testPredict

print(trainPredictPlot.shape, testPredictPlot.shape)
print(trainPredictPlot[0:3], trainPredictPlot[98:101])
print(testPredictPlot[100:103], testPredictPlot[141:])
# Out:
# (144, 1) (144, 1)
# [[         nan]
#  [126.44422913]
#  [132.36642456]] [[309.39538574]
#  [360.55618286]
#  [         nan]]
# [[         nan]
#  [359.63687134]
#  [420.25024414]] [[494.86871338]
#  [454.55612183]
#  [391.55422974]]

# %%
# plot baseline, trainPredict and testPredict
plt.figure(figsize=(10,5))
labels = ['baseline', 'trainPredict', 'testPredict']

#baseline plot
plt.plot(scaler.inverse_transform(scaled), color='black')

#Train Predicted Plot
plt.plot(trainPredictPlot, color='orange')

#Test Predicted Plot
plt.plot(testPredictPlot, color='red')

plt.legend(labels)
plt.show()

# %% [markdown]
# #### Observations:
# - The plot shows that the model is performing well, both on train data and test data
# - The black plot is for complete data, orange for train predicted and red for test predicted
# - Both the orange and red plots are close to the black plot
# - LSTM is performing quiet well on this timeseries dataset
