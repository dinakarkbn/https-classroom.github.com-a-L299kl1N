# %% [markdown]
# # External Lab

# %% [markdown]
# # Part-1

# %% [markdown]
# ## About the dataset
#
# This is perhaps the best known database to be found in the pattern recognition literature. The data set contains 3 classes of 50 instances each, where each class refers to a type of iris plant.  One class is linearly separable from the other 2; the latter are NOT linearly separable from each other.
#
# Attribute Information:
#    1. sepal length in cm
#    2. sepal width in cm
#    3. petal length in cm
#    4. petal width in cm
#    5. class:
#       -- Iris Setosa
#       -- Iris Versicolour
#       -- Iris Virginica

# %% [markdown]
# ### Read the dataset and store it in the dataframe named Iris

# %%
#Import numpy and Pandas modules
import numpy as np
import pandas as pd

# %%
#load the input csv file into a  DataFrame
Iris = pd.read_csv('Iris.csv')

# %%
#Change the column-label names by removing spaces and units
Iris.columns =['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth', 'IrisClass']

#Check if the DataFrame is loaded correctly
Iris.head(3)
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth    IrisClass
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa

# %% [markdown]
# ### Find out the datatypes of each and every column

# %%
#Finding datatype of each column using dtypes attribute
Iris.dtypes
# Out:
# SepalLength    float64
# SepalWidth     float64
# PetalLength    float64
# PetalWidth     float64
# IrisClass       object
# dtype: object

# %%
#Finding datatype of each column using info function
Iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 150 entries, 5.1 to 5.9
# Data columns (total 5 columns):
# SepalLength    150 non-null float64
# SepalWidth     150 non-null float64
# PetalLength    150 non-null float64
# PetalWidth     150 non-null float64
# IrisClass      150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 12.0+ KB

# %% [markdown]
# ### Print top 10 & bottom 10 samples from the dataframe

# %%
#using print function to print top 10 samples
print("Top 10 samples:\n",Iris.head(10))
# Out:
# Top 10 samples:
#     SepalLength  SepalWidth  PetalLength  PetalWidth    IrisClass
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa
# 5          5.4         3.9          1.7         0.4  Iris-setosa
# 6          4.6         3.4          1.4         0.3  Iris-setosa
# 7          5.0         3.4          1.5         0.2  Iris-setosa
# 8          4.4         2.9          1.4         0.2  Iris-setosa
# 9          4.9         3.1          1.5         0.1  Iris-setosa

# %%
#using print function to print bottom 10 samples
print("Bottom 10 samples:\n",Iris.tail(10))
# Out:
# Bottom 10 samples:
#       SepalLength  SepalWidth  PetalLength  PetalWidth       IrisClass
# 140          6.7         3.1          5.6         2.4  Iris-virginica
# 141          6.9         3.1          5.1         2.3  Iris-virginica
# 142          5.8         2.7          5.1         1.9  Iris-virginica
# 143          6.8         3.2          5.9         2.3  Iris-virginica
# 144          6.7         3.3          5.7         2.5  Iris-virginica
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica

# %% [markdown]
# ### Find the shape of the dataset

# %%
#Finding shape using shape attribute
Iris.shape
# Out:
# (150, 5)

# %% [markdown]
# ### Set the index of the dataframe to be the first column

# %%
#using index attribute to set the index to the first column in the DataFrame which is Sepallength
Iris.index = Iris['SepalLength']

# %%
#Check whether the index is correctly set
Iris.head(3)
# Out:
#              SepalLength  SepalWidth  PetalLength  PetalWidth    IrisClass
# SepalLength
# 5.1                  5.1         3.5          1.4         0.2  Iris-setosa
# 4.9                  4.9         3.0          1.4         0.2  Iris-setosa
# 4.7                  4.7         3.2          1.3         0.2  Iris-setosa

# %% [markdown]
# ### Use iloc function to print all the rows of the 3rd column

# %%
#using iloc method to find the all the rows of 3rd column and using print function to print them
print("All Rows of the 3rd column which is PetalLength:\n", Iris.iloc[:,[2]])
# Out:
# All Rows of the 3rd column which is PetalLength:
#               PetalLength
# SepalLength
# 5.1                  1.4
# 4.9                  1.4
# 4.7                  1.3
# 4.6                  1.5
# 5.0                  1.4
# 5.4                  1.7
# 4.6                  1.4
# 5.0                  1.5
# 4.4                  1.4
# 4.9                  1.5
# 5.4                  1.5
# 4.8                  1.6
# 4.8                  1.4
# 4.3                  1.1
# 5.8                  1.2
# 5.7                  1.5
# 5.4                  1.3
# 5.1                  1.4
# 5.7                  1.7
# 5.1                  1.5
# 5.4                  1.7
# 5.1                  1.5
# 4.6                  1.0
# 5.1                  1.7
# 4.8                  1.9
# 5.0                  1.6
# 5.0                  1.6
# 5.2                  1.5
# 5.2                  1.4
# 4.7                  1.6
# ...                  ...
# 6.9                  5.7
# 5.6                  4.9
# ...

# %% [markdown]
# ### Slicing
# Print only the Sepal width and Sepal Length for first 10 rows

# %%
#using print function to print Sepal Width and Sepal Length for first 10 rows
print("Sepal width and Sepal length of first 10 rows:\n", Iris.iloc[:10,[1,0]])
# Out:
# Sepal width and Sepal length of first 10 rows:
#               SepalWidth  SepalLength
# SepalLength
# 5.1                 3.5          5.1
# 4.9                 3.0          4.9
# 4.7                 3.2          4.7
# 4.6                 3.1          4.6
# 5.0                 3.6          5.0
# 5.4                 3.9          5.4
# 4.6                 3.4          4.6
# 5.0                 3.4          5.0
# 4.4                 2.9          4.4
# 4.9                 3.1          4.9

# %% [markdown]
# ### Using Logical statements for indexing
# Print all the columns of row which has class name "Iris-setosa"

# %%
#using print function to print rows having Iris Class as Iris-setosa
print("All the columns for rows which are having Iris Class as Iris-setosa\n", Iris[Iris['IrisClass'] =='Iris-setosa'])
# Out:
# All the columns for rows which are having Iris Class as Iris-setosa
#               SepalLength  SepalWidth  PetalLength  PetalWidth    IrisClass
# SepalLength
# 5.1                  5.1         3.5          1.4         0.2  Iris-setosa
# 4.9                  4.9         3.0          1.4         0.2  Iris-setosa
# 4.7                  4.7         3.2          1.3         0.2  Iris-setosa
# 4.6                  4.6         3.1          1.5         0.2  Iris-setosa
# 5.0                  5.0         3.6          1.4         0.2  Iris-setosa
# 5.4                  5.4         3.9          1.7         0.4  Iris-setosa
# 4.6                  4.6         3.4          1.4         0.3  Iris-setosa
# 5.0                  5.0         3.4          1.5         0.2  Iris-setosa
# 4.4                  4.4         2.9          1.4         0.2  Iris-setosa
# 4.9                  4.9         3.1          1.5         0.1  Iris-setosa
# ...

# %% [markdown]
# ### Multiply Sepal Length and width and store it under the column name "SepalExtra" in the same Iris dataframe

# %%
#Adding a new column SepalExtra
Iris['SepalExtra']=Iris['SepalLength']*Iris['SepalWidth']

# %%
#Check new column is added
Iris.head()
# Out:
#              SepalLength  SepalWidth  PetalLength  PetalWidth    IrisClass  \
# SepalLength
# 5.1                  5.1         3.5          1.4         0.2  Iris-setosa
# 4.9                  4.9         3.0          1.4         0.2  Iris-setosa
# 4.7                  4.7         3.2          1.3         0.2  Iris-setosa
# 4.6                  4.6         3.1          1.5         0.2  Iris-setosa
# 5.0                  5.0         3.6          1.4         0.2  Iris-setosa
#
#              SepalExtra
# SepalLength
# 5.1               17.85
# 4.9               14.70
# 4.7               15.04
# 4.6               14.26
# 5.0               18.00

# %% [markdown]
# ### Find out the mean and variance for each column but for class column

# %%
#Mean of all columns having numeric data using loc method
Iris.loc[:,['SepalLength','SepalWidth','PetalLength','PetalWidth', 'SepalExtra']].mean()
# Out:
# SepalLength     5.843333
# SepalWidth      3.054000
# PetalLength     3.758667
# PetalWidth      1.198667
# SepalExtra     17.806533
# dtype: float64

# %%
#Mean of all columns having numeric data using mean function
Iris.mean(axis=0)
# Out:
# SepalLength     5.843333
# SepalWidth      3.054000
# PetalLength     3.758667
# PetalWidth      1.198667
# SepalExtra     17.806533
# dtype: float64

# %%
#Variance of all columns having numeric data using loc method
Iris.loc[:,['SepalLength','SepalWidth','PetalLength','PetalWidth', 'SepalExtra']].var()
# Out:
# SepalLength     0.685694
# SepalWidth      0.188004
# PetalLength     3.113179
# PetalWidth      0.582414
# SepalExtra     11.348090
# dtype: float64

# %%
#Variance of all columns having numeric data using var function
Iris.var(axis=0)
# Out:
# SepalLength     0.685694
# SepalWidth      0.188004
# PetalLength     3.113179
# PetalWidth      0.582414
# SepalExtra     11.348090
# dtype: float64

# %% [markdown]
# ### Write a function that accepts two numbers as input and prints them - Pass the Sepal length and sepal width of 5th row and print the output

# %%
#Function to print the Sepal Length and Sepal Width of 5th row
def printData(r1, r2):
    print("Sepal Length is ", r1)
    print("Sepal Width is ", r2)

printData(Iris.iloc[4,0], Iris.iloc[4,1])
# Out:
# Sepal Length is  5.0
# Sepal Width is  3.6

# %% [markdown]
# ### Find the range of all the columns in the dataset
#
# *Range = Max value - Min value (in the column)*

# %%
#Maximum of all columns having numeric data
maxCols = Iris.loc[:,['SepalLength','SepalWidth','PetalLength','PetalWidth', 'SepalExtra']].max()
maxCols
# Out:
# SepalLength     7.90
# SepalWidth      4.40
# PetalLength     6.90
# PetalWidth      2.50
# SepalExtra     30.02
# dtype: float64

# %%
#Minimum of all columns having numeric data
minCols = Iris.loc[:,['SepalLength','SepalWidth','PetalLength','PetalWidth', 'SepalExtra']].min()
minCols
# Out:
# SepalLength     4.3
# SepalWidth      2.0
# PetalLength     1.0
# PetalWidth      0.1
# SepalExtra     10.0
# dtype: float64

# %%
#Range of all columns having numeric data
RangeOfCols = maxCols - minCols
RangeOfCols
# Out:
# SepalLength     3.60
# SepalWidth      2.40
# PetalLength     5.90
# PetalWidth      2.40
# SepalExtra     20.02
# dtype: float64

# %% [markdown]
# ### Sort the entire dataset according to the column Petal width

# %%
#Sort the datset on PetalWidth column
Iris.sort_values(by = 'PetalWidth')
# Out:
#              SepalLength  SepalWidth  PetalLength  PetalWidth       IrisClass  \
# SepalLength
# 5.2                  5.2         4.1          1.5         0.1     Iris-setosa
# 4.3                  4.3         3.0          1.1         0.1     Iris-setosa
# 4.9                  4.9         3.1          1.5         0.1     Iris-setosa
# 4.9                  4.9         3.1          1.5         0.1     Iris-setosa
# 4.8                  4.8         3.0          1.4         0.1     Iris-setosa
# 4.9                  4.9         3.1          1.5         0.1     Iris-setosa
# 5.1                  5.1         3.5          1.4         0.2     Iris-setosa
# 5.2                  5.2         3.5          1.5         0.2     Iris-setosa
# 5.2                  5.2         3.4          1.4         0.2     Iris-setosa
# 4.7                  4.7         3.2          1.6         0.2     Iris-setosa
# 4.8                  4.8         3.1          1.6         0.2     Iris-setosa
# ...

# %% [markdown]
# ### Remove the new column "SepalExtra" from the dataframe

# %%
#Remove SepalExtra column using drop function.Column will be present in original DataFrame
Iris.drop('SepalExtra', axis=1)
# Out:
#              SepalLength  SepalWidth  PetalLength  PetalWidth       IrisClass
# SepalLength
# 5.1                  5.1         3.5          1.4         0.2     Iris-setosa
# 4.9                  4.9         3.0          1.4         0.2     Iris-setosa
# 4.7                  4.7         3.2          1.3         0.2     Iris-setosa
# 4.6                  4.6         3.1          1.5         0.2     Iris-setosa
# 5.0                  5.0         3.6          1.4         0.2     Iris-setosa
# 5.4                  5.4         3.9          1.7         0.4     Iris-setosa
# 4.6                  4.6         3.4          1.4         0.3     Iris-setosa
# 5.0                  5.0         3.4          1.5         0.2     Iris-setosa
# 4.4                  4.4         2.9          1.4         0.2     Iris-setosa
# 4.9                  4.9         3.1          1.5         0.1     Iris-setosa
# 5.4                  5.4         3.7          1.5         0.2     Iris-setosa
# ...

# %%
#Remove SepalExtra column using del method.Column is removed from original DataFrame.
del[Iris['SepalExtra']]

# %%
#Check that SepalExtra column is removed in Iris DataFrame
Iris.head()
# Out:
#              SepalLength  SepalWidth  PetalLength  PetalWidth    IrisClass
# SepalLength
# 5.1                  5.1         3.5          1.4         0.2  Iris-setosa
# 4.9                  4.9         3.0          1.4         0.2  Iris-setosa
# 4.7                  4.7         3.2          1.3         0.2  Iris-setosa
# 4.6                  4.6         3.1          1.5         0.2  Iris-setosa
# 5.0                  5.0         3.6          1.4         0.2  Iris-setosa

# %% [markdown]
# ### Take only the top 10 rows of the dataset with only first 3 columns and store it in a dataframe named "IrisSubset"

# %%
#storing top 10 rows and first 3 columns data in a new DataFrame
IrisSubset = Iris.iloc[0:9,0:3]

# %%
IrisSubset
# Out:
#              SepalLength  SepalWidth  PetalLength
# SepalLength
# 5.1                  5.1         3.5          1.4
# 4.9                  4.9         3.0          1.4
# 4.7                  4.7         3.2          1.3
# 4.6                  4.6         3.1          1.5
# 5.0                  5.0         3.6          1.4
# 5.4                  5.4         3.9          1.7
# 4.6                  4.6         3.4          1.4
# 5.0                  5.0         3.4          1.5
# 4.4                  4.4         2.9          1.4

# %% [markdown]
# # Part-2

# %% [markdown]
# ## The dataset HR contains information collected from the survey floated by a HR within the company.
#
#
# As a part of this lab, you are expected to answer the below questions

# %% [markdown]
# ### Import numpy and Pandas

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %% [markdown]
# ### Import the dataset (Note: The dataset is in .txt format) - Make sure to use delimiters

# %%
#Load the Tab separated text file
hr = pd.read_csv('HR_external.txt', sep='\t')
hr
# Out:
#      Individual  Attrition  Age  BusinessTravel  DailyRate  Department  \
# 0           Ind1       Yes   41               1       1102           1
# 1           Ind2        No   49               2        279           2
# 2           Ind3       Yes   37               1       1373           2
# 3           Ind4        No   33               2       1392           2
# 4           Ind5        No   27               1        591           2
# 5           Ind6        No   32               2       1005           2
# 6           Ind7        No   59               1       1324           2
# 7           Ind8        No   30               1       1358           2
# 8           Ind9        No   38               2        216           2
# 9          Ind10        No   36               1       1299           2
# 10         Ind11        No   35               1        809           2
# 11         Ind12        No   29               1        153           2
# ...

# %% [markdown]
# ### Print the no of rows and columns in the dataset

# %%
#using print function to print no. of rows
print("Number of Rows in HR dataset:\n", len(hr.index))
# Out:
# Number of Rows in HR dataset:
#  1470

# %%
#using print function to print no.of columns
print("Number of Columns in HR dataset:\n", len(hr.columns))
# Out:
# Number of Columns in HR dataset:
#  35

# %% [markdown]
# ### Find out the type of each and every column in the dataset

# %%
#Finding datatype of each column using dtypes attribute
hr.dtypes
# Out:
# Individual                  object
# Attrition                   object
# Age                          int64
# BusinessTravel               int64
# DailyRate                    int64
# Department                   int64
# DistanceFromHome             int64
# Education                    int64
# EducationField               int64
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                       int64
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                      int64
# JobSatisfaction              int64
# MaritalStatus                int64
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# OverTime                     int64
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
#Finding datatype of each column using info function
hr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
# Individual                  1470 non-null object
# Attrition                   1470 non-null object
# Age                         1470 non-null int64
# BusinessTravel              1470 non-null int64
# DailyRate                   1470 non-null int64
# Department                  1470 non-null int64
# DistanceFromHome            1470 non-null int64
# Education                   1470 non-null int64
# EducationField              1470 non-null int64
# EmployeeCount               1470 non-null int64
# EmployeeNumber              1470 non-null int64
# EnvironmentSatisfaction     1470 non-null int64
# Gender                      1470 non-null int64
# HourlyRate                  1470 non-null int64
# JobInvolvement              1470 non-null int64
# JobLevel                    1470 non-null int64
# JobRole                     1470 non-null int64
# ...

# %% [markdown]
# ### Print out all the rows from 3rd column to 10th columns

# %%
#using iloc method to select and print function to print
print("All Rows of hr daset from 3rd column to 10th column:\n", hr.iloc[:,2:10])
# Out:
# All Rows of hr daset from 3rd column to 10th column:
#        Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0      41               1       1102           1                 1          2
# 1      49               2        279           2                 8          1
# 2      37               1       1373           2                 2          2
# 3      33               2       1392           2                 3          4
# 4      27               1        591           2                 2          1
# 5      32               2       1005           2                 2          2
# 6      59               1       1324           2                 3          3
# 7      30               1       1358           2                24          1
# 8      38               2        216           2                23          3
# 9      36               1       1299           2                27          3
# ...

# %% [markdown]
# ### Find out the no of male & female employees in the company
#
# *Hint: Use can use a condition to find out the no of 1s and 0s in gender and sum it*

# %%
#using unique to find the values which represent Male and Female empolyees
hr.Gender.unique()
# Out:
# array([2, 1], dtype=int64)

# %%
#Assume Male employee is represented by 1 to find total no of Male employees
len(hr[hr['Gender'] == 1].index)
# Out:
# 882

# %%
#Assume Female employee is represented by 2 to find total no of Female employees
len(hr[hr['Gender'] == 2].index)
# Out:
# 588

# %%
#Check if sum of male and female employee counts gives total employee count
len(hr[hr['Gender'] == 1].index) + len(hr[hr['Gender'] == 2].index)
# Out:
# 1470

# %%
#using value_counts function to find count of Male and Female and employees
hr['Gender'].value_counts()
# Out:
# 1    882
# 2    588
# Name: Gender, dtype: int64

# %% [markdown]
# ### Find out the IQR for the column - Age
#
# *Hint: IQR - Interquartile range = 75th percentile - 25th percentile*

# %%
#finding Q1 for Age column
hr['Age'].quantile(q=0.25)
# Out:
# 30.0

# %%
#finding Q3 for Age column
hr['Age'].quantile(q=0.75)
# Out:
# 43.0

# %%
#finding IQR
iqr = hr['Age'].quantile(q=0.75) - hr['Age'].quantile(q=0.25)
iqr
# Out:
# 13.0

# %% [markdown]
# ### Find out the mean, median and variance for the column - DailyRate

# %%
#Mean for DailyRate column
hr['DailyRate'].mean()
# Out:
# 802.4857142857143

# %%
#Median for DailyRate column
hr['DailyRate'].median()
# Out:
# 802.0

# %%
#Variance for DailyRate column
hr['DailyRate'].var()
# Out:
# 162819.59373723628

# %% [markdown]
# ### Plot the attrition column (Since it is a categorical variable, chose the plot accordingly)

# %%
#import matplotlib
from matplotlib import pyplot as plt

# %%
#Plottig PieChart for the Attrition Column, which shows the Attrition percent of all employees
hr['Attrition'].value_counts()
plt.pie(hr['Attrition'].value_counts(),labels=hr['Attrition'].value_counts().index, startangle=60,autopct='%1.1f%%', 
       colors=['#4CAC40','#FF0000'])
plt.title("\nAttrition Percent of all Individuals")
plt.show()

# %% [markdown]
# ### Plot Total working years using matplotlib plot function

# %%
#2D line Plot for Total working years
plt.plot(hr.index, hr['TotalWorkingYears'], label='Total Working Years')
plt.legend()
plt.xlabel('No. of Individuals')
plt.ylabel('Total Working Years for each Individual')
plt.show()
